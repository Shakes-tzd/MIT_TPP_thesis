# %%
# %cd
# !pwd
# Out:
# /home/tzd
# /home/tzd

# %%
#https://www.youtube.com/watch?v=XjCPUkYc62Q

# %%
import warnings
warnings.filterwarnings("ignore")
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
import os
os.chdir('/home/tzd/fs03/d1/tzd/Data_analysis/RAworkflow')
# %run ./My_Modules/DataSetUP10VAR.ipynb
#FmodelDF
# getNoASGM():       => Hg0no_ASGM dataframe; in correct units
# get_model(region): => Hg0_modified; in correct units (takes gridbox region in Peru as input)
# getLoRes():        => Hg0 baseline with ASGM low resulution in correct units
# getHiRes():        => Hg0 baseline with ASGM high resulution in correct units  
# getNoASGM():       => Hg0 baseline without ASGM low resulution in correct units  
# get_obs_d():       => obs_Hg0; original observations daily mean values
# get_detrended_obs(): => Obs_detrended; return detrended observations
# get_detrended_model(model): => This function takes in a dataframe of model outputs and returns the detrended version of that model output
# getIQR_Dd(model): This function takes in a dataframe of model outputs and returns the detrended IQR 
# getIQR(model): => This function takes in a dataframe of model outputs and returns the IQR
# Out:
# boxes().shape[0]
# # getNoASGM():       => Hg0no_ASGM dataframe; in correct units
# # get_model(region): => Hg0_modified; in correct units (takes gridbox region in Peru as input)
# # getLoRes():        => Hg0 baseline with ASGM low resulution in correct units
# # getHiRes():        => Hg0 baseline with ASGM high resulution in correct units
# # getNoASGM():       => Hg0 baseline without ASGM low resulution in correct units
# # get_obs_d():       => obs_Hg0; original observations daily mean values
# # get_detrended_obs(): => Obs_detrended; return detrended observations
# # get_detrended_model(model): => This function takes in a dataframe of model outputs
#                                 and returns the detrended version of that model output
# # getObsIQR(obs): This function takes observations and returns the IQR
# # getIQR_Dd(model): This function takes in a dataframe of model outputs and returns the detrended IQR
# # getIQR(model): => This function takes in a dataframe of model outputs and returns the IQR
# # getBoxesAround()
# # GBaroundIQRs()
# # GBaroundMean()
# # GBaround90th()
#
#  Copy the collowing code to get the constant term
# getConst(refnum): refnum is the number of reference grid cells required
#
#
#  Copy the regions included in calculation following code to get the constant term
#
# Spun_sigs=multiSite('spun',refnum)
# Npun_sigs = multiSite('npun',refnum)
# Mdd_sigs = multiSite('mdd',refnum)
# Aqp_sigs = multiSite('aqp',refnum)
# Apr_sigs = multiSite('apr',refnum) :refnum is the number of reference grid cells required

# %% [markdown]
# # Characteristics Time Series

# %% [markdown]
# ## Characteristics of Observation Time Series

# %%
plt.figure(figsize=(15,5))
plt.title('Measured Hg Concentrations at Chalcataya Monitoring Station')
get_obs_d().value.plot(color = 'red',label = 'Observations')
# plt.legend()
plt.ylabel('[Hg$^0$] (ng m$^{-3}$)')
plt.show()

# %%
obs=get_obs_d()
obs.index = pd.to_datetime(obs.index)

# %%
results = seasonal_decompose(obs, model='additive',period=30)

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1, figsize=(15,8))
results.trend.plot(ax=ax1)
ax1.set(ylabel='Trend')
results.seasonal.plot(ax=ax2)
ax2.set(ylabel='Seasonal')
results.resid.plot(ax=ax3)
ax3.set(ylabel='Residuals')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# Based on the trend plot in the figure above, there appears to be an overall upwards trend in the observed mercury concentration over the two years in which the data was recorded
#
# We can see that there is definite seasonality in the data, causing prices to fluctuate by 0.2 over the course of a month.
#
# The residual plot show us that there is randomness in the observed concentration of Hg in the atmosphere
#
# Next we weill create the same plot for the model output tio figure out if GEOS Chem captures all these characteristic of the observed data

# %% [markdown]
# ## Characteristics of Model Time Series

# %%
GCno_asgm=getNoASGM()
GC_asgm=getLoRes()

# %%
plt.figure(figsize=(15,5))
plt.title('Predicted Hg Concentrations in GOES Chem Model')
# getNoASGM().SpeciesConc_Hg0.plot(color = 'green',label = 'Baseline with No ASGM Emissions ')
GC_asgm.SpeciesConc_Hg0.plot(color = 'blue',label = 'Baseline with ASGM Emissions ')
# get_obs_d().value.plot(color = 'red',label = 'Observations')
plt.legend()
plt.ylabel('[Hg$^0$] (ng m$^{-3}$)')
plt.show()

# %%
GC_asgm.index = pd.to_datetime(GC_asgm.index)

# %%
results_model = seasonal_decompose(GC_asgm, model='additive',period=30)

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1, figsize=(15,8))
results_model.trend.plot(ax=ax1)
ax1.set(ylabel='Trend')
results_model.seasonal.plot(ax=ax2)
ax2.set(ylabel='Seasonal')
results_model.resid.plot(ax=ax3)
ax3.set(ylabel='Residuals')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# Based on the trend plot in the figure above, there appears to be no overall upwards or downward trend in the modelled mercury concentration over the two years simulated in GEOS Chem
#
# We can see that there is definite seasonality in the data, causing prices to fluctuate by 0.125 over the course of a month.
#
# The residual plot shows us that there is randomness in the modelled concentration of Hg in the atmosphere
#
# Next we weill create the same plot for the model output tio figure out if GEOS Chem captures all these characteristic of the observed data

# %% [markdown]
# # Comparison of Time Series

# %% [markdown]
# ## Plot of time series before detrending

# %%
plt.figure(figsize=(15,5))
plt.title('Predicted Hg Concentrations when ASGM Emissions Are Turned Off vs when Turned On in GEOS-Chem')
GCno_asgm.SpeciesConc_Hg0.plot(color = 'green',label = 'Baseline with No ASGM Emissions ')
GC_asgm.SpeciesConc_Hg0.plot(color = 'blue',label = 'Baseline with ASGM Emissions ')
# get_obs_d().value.plot(color = 'red',label = 'Observations')
plt.legend()
plt.ylabel('[Hg$^0$] (ng m$^{-3}$)')
plt.show()

# %% [markdown]
# According to the plot above we can tell that GEOS-Chem attributes the Hg concentration at Chalcataya to ASGM emissions.
#
# Consequently, we can conclude that the model asserts that the Hg concentration in the atmosphere at Chalcataya is mostly due to Hg emissions from ASGM activities in the surrounding reagion. if we trust the GEOS-Chem models prediction of the Hg concentrations, we may use it to explaint he observed concentrations in the atmosphere.

# %%
plt.figure(figsize=(8,5))
plt.title('Predicted Hg Concentrations when ASGM Emissions are \nTurned Off vs when Turned On in GEOS-Chem',size=12,fontweight="bold")
sns.kdeplot(data=GC_asgm.SpeciesConc_Hg0, fill=False,color = 'blue',label = 'Reference with ASGM Emissions ',bw_adjust=0.5)
sns.kdeplot(data=GCno_asgm.SpeciesConc_Hg0, fill=False,color = 'green',label = 'Baseline with No ASGM Emissions ',bw_adjust=0.5)
plt.legend()
plt.xlabel('[Hg$^0$] (ng m$^{-3}$)')
plt.show()

# %% [markdown]
# ## How do the observed concentrations in the Atmosphere compare with the modeled Hg concentrations

# %%
obsNC=obs.loc[:'2015-7-31']
GC_asgmNC=GC_asgm.loc[:'2015-7-31']

# %%
plt.figure(figsize=(15,5))
plt.title('Measured Hg Concentrations vs Predicted Low Resolution Hg Concentrations in GOES Chem Model')
GC_asgm.SpeciesConc_Hg0.plot(color = 'blue',label = 'Baseline with ASGM Emissions ')
obs.value.plot(color = 'red',label = 'Observations')
plt.legend()
plt.ylabel('[Hg$^0$] (ng m$^{-3}$)')
plt.xlabel('Time')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title('Measured Hg Concentrations vs Predicted Low Resolution Hg Concentrations in GOES Chem Model')
GC_asgmNC.SpeciesConc_Hg0.plot(color = 'blue',label = 'Baseline with ASGM Emissions ')
obsNC.value.plot(color = 'red',label = 'Observations')
plt.legend()
plt.ylabel('[Hg$^0$] (ng m$^{-3}$)')
plt.xlabel('Time')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() 
GC_asgmNC_scaled = scaler.fit_transform(GC_asgmNC)
obsNC_scaled = scaler.fit_transform(obsNC)

# %%
plt.figure(figsize=(8,5))
plt.title('Predicted Hg Concentrations when ASGM Emissions are \nTurned Off vs when Turned On in GEOS-Chem',size=12,fontweight="bold")
sns.kdeplot(data=GC_asgmNC.SpeciesConc_Hg0, fill=False,color = 'blue',label = 'Baseline with \nASGM Emissions ',bw_adjust=0.5)
sns.kdeplot(data=obsNC.value, fill=False,color = 'red',label = 'Observations',bw_adjust=0.5)
plt.legend()
plt.xlabel('[Hg$^0$] (ng m$^{-3}$)')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
#plt.figure(figsize=(8,5))
plt.title('Predicted Hg Concentrations when ASGM Emissions are \nTurned Off vs when Turned On in GEOS-Chem',size=12,fontweight="bold")
sns.kdeplot(data=GC_asgmNC_scaled.squeeze(),ax =ax,color = 'blue', fill=False,label = 'Baseline with \nASGM Emissions ',bw_adjust=0.5)
sns.kdeplot(data=obsNC_scaled.squeeze(),ax =ax,color = 'red', fill=False,label = 'Observations',bw_adjust=0.5)
plt.legend()
plt.xlabel('[Hg$^0$] (ng m$^{-3}$)')
plt.show()

# %%
myMax=max(max(obsNC.value),max(GC_asgmNC.SpeciesConc_Hg0))

# %%
from scipy import stats
corr=stats.spearmanr(obsNC.value, GC_asgmNC.SpeciesConc_Hg0)
# from scipy import stats
# stats.spearmanr([1,2,3,4,5], [5,6,7,8,7])
corr[0]
# Out:
# 0.05160853470158879

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(obsNC.value,GC_asgmNC.SpeciesConc_Hg0, ci =95)
plt.xlabel('Observations [Hg$^0$] (ng m$^{-3}$)')
plt.ylabel('Modelled [Hg$^0$] (ng m$^{-3}$)')
plt.plot([0,myMax],[0,myMax],c='r',linestyle = 'dashed')
plt.annotate("$R^2$ = {:.3f}".format(corr[0]), (0, 1.5))
plt.annotate("p_value = {:.3f}".format(corr[1]), (0, 1.4))
# To show the plot
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title('Measured Hg Concentrations vs Predicted No ASGM Emissions Hg Concentrations in GOES Chem Model')
getNoASGM().SpeciesConc_Hg0.plot(color = 'green',label = 'Baseline with No ASGM Emissions ')
get_obs_d().value.plot(color = 'red',label = 'Observations')
plt.legend()
plt.ylabel('[Hg$^0$] (ng m$^{-3}$)')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title('Measured Hg Concentrations vs Predicted High Resolution Hg Concentrations in GOES Chem Model')
getHiRes().SpeciesConc_Hg0.plot(color = 'purple',label = 'High Resolution Baseline with ASGM Emissions ')
get_obs_d().value.plot(color = 'red',label = 'Observations')
plt.legend()
plt.ylabel('[Hg$^0$] (ng m$^{-3}$)')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title('Predicted Hg Concentrations in GOES Chem Model')
(getNoASGM()).SpeciesConc_Hg0.plot(color = 'green',label = 'Baseline with No ASGM Emissions ')
(getLoRes()).SpeciesConc_Hg0.plot(color = 'blue',label = 'Low Resolution Baseline with ASGM Emissions ')
(getHiRes()).SpeciesConc_Hg0.plot(color = 'purple',label = 'High Resolution Baseline with ASGM Emissions ')
#get_detrended_obs().value.plot(color = 'red',label = 'Observations')
plt.legend()
plt.ylabel('[Hg$^0$] (ng m$^{-3}$)')
plt.show()

# %% [markdown]
# ## Plot of time series after detrending

# %%
plt.figure(figsize=(15,5))
plt.title('Detrended Predicted Hg Concentrations in GOES Chem Model')
get_detrended_model(getNoASGM()).SpeciesConc_Hg0.plot(color = 'green',label = 'Baseline with No ASGM Emissions ')
get_detrended_model(getLoRes()).SpeciesConc_Hg0.plot(color = 'blue',label = 'Low Resolution Baseline with ASGM Emissions ')
get_detrended_model(getHiRes()).SpeciesConc_Hg0.plot(color = 'purple',label = 'High Resolution Baseline with ASGM Emissions ')
#get_detrended_obs().value.plot(color = 'red',label = 'Observations')
plt.legend()
plt.ylabel('[Hg$^0$] (ng m$^{-3}$)')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title('Measured Hg Concentrations vs Predicted Hg Concentrations in GOES Chem Model')
get_detrended_model(getNoASGM()).SpeciesConc_Hg0.plot(color = 'green',label = 'Baseline with No ASGM Emissions ')
get_detrended_model(getLoRes()).SpeciesConc_Hg0.plot(color = 'blue',label = 'Low Resolution Baseline with ASGM Emissions ')
get_detrended_model(getHiRes()).SpeciesConc_Hg0.plot(color = 'purple',label = 'High Resolution Baseline with ASGM Emissions ')
get_detrended_obs().value.plot(color = 'red',label = 'Observations')
plt.legend()
plt.ylabel('[Hg$^0$] (ng m$^{-3}$)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 6>()
#       4 get_detrended_model(getLoRes()).SpeciesConc_Hg0.plot(color = 'blue',label = 'Low Resolution Baseline with ASGM Emissions ')
#       5 get_detrended_model(getHiRes()).SpeciesConc_Hg0.plot(color = 'purple',label = 'High Resolution Baseline with ASGM Emissions ')
# ----> 6 get_detrended_obs().value.plot(color = 'red',label = 'Observations')
#       7 plt.legend()
#       8 plt.ylabel('[Hg$^0$] (ng m$^{-3}$)')
#
# File ~/anaconda3/envs/Jlab/lib/python3.9/site-packages/pandas/plotting/_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/anaconda3/envs/Jlab/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/anaconda3/envs/Jlab/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:329, in MPLPlot.generate(self)
#     327 self._compute_plot_data()
#     328 self._setup_subplots()
# --> 329 self._make_plot()
#     330 self._add_table()
#     331 self._make_legend()
#
# File ~/anaconda3/envs/Jlab/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1226, in LinePlot._make_plot(self)
#    1223 label = self._mark_right_label(label, index=i)
#    1224 kwds["label"] = label
# -> 1226 newlines = plotf(
#    1227     ax,
#    1228     x,
#    1229     y,
#    1230     style=style,
#    1231     column_num=i,
#    1232     stacking_id=stacking_id,
#    1233     is_errorbar=is_errorbar,
#    1234     **kwds,
#    1235 )
#    1236 self._append_legend_handles_labels(newlines[0], label)
#    1238 if self._is_ts_plot():
#    1239
#    1240     # reset of xlim should be used for ts data
#    1241     # TODO: GH28021, should find a way to change view limit on xaxis
#
# File ~/anaconda3/envs/Jlab/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1278, in LinePlot._ts_plot(cls, ax, x, data, style, **kwds)
#    1276 lines = cls._plot(ax, data.index, data.values, style=style, **kwds)
#    1277 # set date formatter, locators and rescale limits
# -> 1278 format_dateaxis(ax, ax.freq, data.index)
#    1279 return lines
#
# File ~/anaconda3/envs/Jlab/lib/python3.9/site-packages/pandas/plotting/_matplotlib/timeseries.py:331, in format_dateaxis(subplot, freq, index)
#     329     subplot.xaxis.set_major_formatter(TimeSeries_TimedeltaFormatter())
#     330 else:
# --> 331     raise TypeError("index type not supported")
#     333 pylab.draw_if_interactive()
#
# TypeError: index type not supported

# %%
plt.figure(figsize=(15,5))
plt.title('Measured Hg Concentrations vs Predicted Hg Concentrations with No ASGM in GOES Chem Model')
get_detrended_model(getNoASGM()).SpeciesConc_Hg0.plot(color = 'green',label = 'Baseline with No ASGM Emissions ')
#get_detrended_model(getLoRes()).SpeciesConc_Hg0.plot(color = 'blue',label = 'Low Resolution Baseline with ASGM Emissions ')
#get_detrended_model(getHiRes()).SpeciesConc_Hg0.plot(color = 'purple',label = 'High Resolution Baseline with ASGM Emissions ')
get_detrended_obs().value.plot(color = 'red',label = 'Observations')
plt.legend()
plt.ylabel('[Hg$^0$] (ng m$^{-3}$)')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title('Measured Hg Concentrations vs Predicted Hg Concentrations with Low Resolution ASGM Emissions in GOES Chem Model')
#get_detrended_model(getNoASGM()).SpeciesConc_Hg0.plot(color = 'green',label = 'Baseline with No ASGM Emissions ')
get_detrended_model(getLoRes()).SpeciesConc_Hg0.plot(color = 'blue',label = 'Low Resolution Baseline with ASGM Emissions ')
#get_detrended_model(getHiRes()).SpeciesConc_Hg0.plot(color = 'purple',label = 'High Resolution Baseline with ASGM Emissions ')
get_detrended_obs().value.plot(color = 'red',label = 'Observations')
plt.legend()
plt.ylabel('[Hg$^0$] (ng m$^{-3}$)')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title('Measured Hg Concentrations vs Predicted Hg Concentrations with High Resolution ASGM Emissions in GOES Chem Model')
#get_detrended_model(getNoASGM()).SpeciesConc_Hg0.plot(color = 'green',label = 'Baseline with No ASGM Emissions ')
#get_detrended_model(getLoRes()).SpeciesConc_Hg0.plot(color = 'blue',label = 'Low Resolution Baseline with ASGM Emissions ')
get_detrended_model(getHiRes()).SpeciesConc_Hg0.plot(color = 'purple',label = 'High Resolution Baseline with ASGM Emissions ')
get_detrended_obs().value.plot(color = 'red',label = 'Observations')
plt.legend()
plt.ylabel('[Hg$^0$] (ng m$^{-3}$)')
plt.show()
