# %%
# %matplotlib inline


import numpy as np

import xarray as xr
import geoplot.crs as gcrs
import regionmask 
import geopandas as gpd
import geoplot as gplt

import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import numpy.ma as ma
import csv
import netCDF4 as nc
import scipy
import pandas
from glob import glob
import pandas as pd
from scipy.interpolate import Rbf

np.seterr(invalid='ignore'); # disable a warning from matplotlib and cartopy

# %%
# WILL USE THESE UNITS FOR CONVERSIONS LATER, INITIALIZE HERE
R=8.317 #J/(mol K)
MW=200.59 #molecular weight of hg in g/mol
ppt=1e-12 #current [Hg0] units is ex. .03 ppt, where ppt is 1e-12
stdpressure=101325 #pascals
stdtemp=273.15 #Kelvins

# %%
def fix_ds(ds):
    return ds.assign_coords({'LON':ds.LON, 'LAT':ds.LAT, 'ETAC':ds.ETAC, 'ETAE':ds.ETAE, 
                            'time':pd.to_datetime(ds.attrs['Start_Date'], format='%Y%m%d')}
                           ).expand_dims('time')

#open base files (with artisnal mining)
ds_base=xr.open_mfdataset('/net/fs03/d1/angot/postdoc/GMA_2018/my_runs/production_runs_2x2.5/BASE/netcdf_output/trac.2015*.nc',
                         preprocess=fix_ds, concat_dim=['time'], combine='by_coords')

# %%
ds_base
# Out:
# <xarray.Dataset>
# Dimensions:             (Alt-000: 1, Alt-001: 38, Alt-002: 47, Alt-003: 48, Lat-000: 91, Lon-000: 144, time: 12)
# Coordinates:
#     LON                 (Lon-000) float32 dask.array<chunksize=(144,), meta=np.ndarray>
#     LAT                 (Lat-000) float32 dask.array<chunksize=(91,), meta=np.ndarray>
#     ETAC                (Alt-002) float32 dask.array<chunksize=(47,), meta=np.ndarray>
#     ETAE                (Alt-003) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#   * time                (time) datetime64[ns] 2015-01-01 ... 2015-12-01
# Dimensions without coordinates: Alt-000, Alt-001, Alt-002, Alt-003, Lat-000, Lon-000
# Data variables:
#     Ap                  (time, Alt-003) float32 dask.array<chunksize=(1, 48), meta=np.ndarray>
#     Bp                  (time, Alt-003) float32 dask.array<chunksize=(1, 48), meta=np.ndarray>
# ...

# %%
#create shortened dataset for ds_base
ds_b=xr.Dataset()
ds_b['IJ-AVG-S_Hg0']=(ds_base['IJ-AVG-S__Hg0'])
ds_b['IJ-AVG-S_HgP']=(ds_base['IJ-AVG-S__HgP'])
ds_b['IJ-AVG-S_Hg2']=(ds_base['IJ-AVG-S__Hg2'])
ds_b['BXHGHT-S_BXHEIGHT']=(ds_base['BXHGHT-S__BXHEIGHT'])
ds_b['BXHGHT-S_T']=(ds_base['BXHGHT-S__T']) #Kelvins
ds_b['BXHGHT-S_PMID']=(ds_base['BXHGHT-S__PMID'])*100 #hpa to pa
ds_b['BXHGHT-S_PMID'].attrs['unit']='Pa'

df_base = ds_b.to_dataframe()
df_Bsurf=df_base

# #######changing units to ng/m3 from ppt using P/(TR)*pptv*MW #########

'''P/(TR)*ppt*MW --> Pa/(K*J/(mol*K))*ppt*g/mol --> g/m3*ppt. to get rid of ppt, multiply by 1e-12.'''
species=['IJ-AVG-S_Hg0', 'IJ-AVG-S_HgP', 'IJ-AVG-S_Hg2']
for s in species:
    df_Bsurf[s]= df_Bsurf[s]*ppt* stdpressure/(stdtemp*R)*MW*1e9 #1e9 converts from g to ng

#now units are ng/m3
ds_b['IJ-AVG-S_Hg0'].attrs['unit']='ng/m3'
df_Bsurf
# Out:
#                                       LON   LAT      ETAC  IJ-AVG-S_Hg0  \
# Alt-002 Lat-000 Lon-000 time
# 0       0       0       2015-01-01 -180.0 -89.5  0.992500      0.296195
#                         2015-02-01 -180.0 -89.5  0.992500      0.375870
#                         2015-03-01 -180.0 -89.5  0.992500      0.543671
#                         2015-04-01 -180.0 -89.5  0.992500      0.700514
#                         2015-05-01 -180.0 -89.5  0.992500      0.807922
# ...                                   ...   ...       ...           ...
# 46      90      143     2015-08-01  177.5  89.5  0.000028      0.057536
#                         2015-09-01  177.5  89.5  0.000028      0.053611
#                         2015-10-01  177.5  89.5  0.000028      0.047656
#                         2015-11-01  177.5  89.5  0.000028      0.038048
#                         2015-12-01  177.5  89.5  0.000028      0.038596
#
#                                     IJ-AVG-S_HgP  IJ-AVG-S_Hg2  \
# ...

# %%
dsHg=df_Bsurf.to_xarray() #change to xarray dataset so you can graph it using prev method

#coordinates got messed up so fix it
drop=dsHg.drop('Lon-000')
new=drop.drop('Lat-000')
fixed_latlon=new.assign_coords({'Lon-000':np.arange(-180., 180., 2.5), 'Lat-000':np.arange(-90., 90., 1.98)})

# dsHg.set_coords()
fixed_latlon
# Out:
# <xarray.Dataset>
# Dimensions:            (Alt-002: 47, Lat-000: 91, Lon-000: 144, time: 12)
# Coordinates:
#   * Alt-002            (Alt-002) int64 0 1 2 3 4 5 6 7 ... 40 41 42 43 44 45 46
#   * time               (time) datetime64[ns] 2015-01-01 ... 2015-12-01
#   * Lon-000            (Lon-000) float64 -180.0 -177.5 -175.0 ... 175.0 177.5
#   * Lat-000            (Lat-000) float64 -90.0 -88.02 -86.04 ... 86.22 88.2
# Data variables:
#     LON                (Alt-002, Lat-000, Lon-000, time) float32 -180.0 ... 1...
#     LAT                (Alt-002, Lat-000, Lon-000, time) float32 -89.5 ... 89.5
#     ETAC               (Alt-002, Lat-000, Lon-000, time) float32 0.9925 ... 2...
#     IJ-AVG-S_Hg0       (Alt-002, Lat-000, Lon-000, time) float64 0.2962 ... 0...
#     IJ-AVG-S_HgP       (Alt-002, Lat-000, Lon-000, time) float64 0.0007551 .....
#     IJ-AVG-S_Hg2       (Alt-002, Lat-000, Lon-000, time) float64 0.1932 ... 1...
# ...

# %%
fig = plt.figure(figsize=[16,8])
ax = fig.add_subplot(111, projection=ccrs.PlateCarree())

fixed_latlon['IJ-AVG-S_Hg0'].mean(dim='time').plot(ax=ax, #set the axis
                        levels = np.arange(0, .5, .01), #set the levels for our colorbars
                       extend='both',#extend the colorbar in both directions
                       transform=ccrs.PlateCarree(), #fit data into map
                       cbar_kwargs={'label':ds_b['IJ-AVG-S_Hg0'].attrs['unit']}, #label our colorbar (use ds_a just to get units)
                        cmap='hsv')  #choose color for our colorbar

ax.coastlines() #add coastlines
plt.title('Monthly Averaged Hg0 Difference (Artisinal Mining - No Artisinal Mining)', fontsize = 16); #title
av=df_d.resample('AS').mean()
print('Global Average Value from Model: ',av['IJ-AVG-S_Hg0'][0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-48893ad0d1bd> in <module>
#       2 ax = fig.add_subplot(111, projection=ccrs.PlateCarree())
#       3
# ----> 4 fixed_latlon['IJ-AVG-S_Hg0'].mean(dim='time').plot(ax=ax, #set the axis
#       5                         levels = np.arange(0, .5, .01), #set the levels for our colorbars
#       6                        extend='both',#extend the colorbar in both directions
#
# ~/anaconda3/envs/UniToro/lib/python3.8/site-packages/xarray/plot/plot.py in __call__(self, **kwargs)
#     444
#     445     def __call__(self, **kwargs):
# --> 446         return plot(self._da, **kwargs)
#     447
#     448     # we can't use functools.wraps here since that also modifies the name / qualname
#
# ...

# %%
Hgsurf = fixed_latlon['IJ-AVG-S_Hg0'].isel(time=0)
Hgsurf
# Out:
# <xarray.DataArray 'IJ-AVG-S_Hg0' (Alt-002: 47, Lat-000: 91, Lon-000: 144)>
# array([[[0.29619477, 0.29619477, 0.29619477, ..., 0.29619474,
#          0.29619477, 0.29619477],
#         [0.29589168, 0.29587782, 0.29585739, ..., 0.29590141,
#          0.29589704, 0.29589795],
#         [0.3077237 , 0.30862728, 0.30902861, ..., 0.30751606,
#          0.3071725 , 0.30706141],
#         ...,
#         [1.3288736 , 1.32767542, 1.32639309, ..., 1.33135836,
#          1.33071452, 1.32989064],
#         [1.30483016, 1.30483089, 1.30483198, ..., 1.30483089,
#          1.30483077, 1.30483004],
#         [1.30488448, 1.30488448, 1.30488448, ..., 1.30488448,
#          1.30488448, 1.30488448]],
#
#        [[0.28986893, 0.28986893, 0.28986893, ..., 0.2898689 ,
#          0.28986893, 0.28986893],
#         [0.29027736, 0.29026751, 0.29025117, ..., 0.29025902,
#          0.29026972, 0.29028579],
#         [0.30228071, 0.30257659, 0.30297344, ..., 0.30246801,
#          0.30208705, 0.30198462],
# ...

# %%
Hgsurf.plot()
# Out:
# (array([2.32162e+05, 1.29363e+05, 2.39452e+05, 1.38010e+04, 7.91000e+02,
#         2.72000e+02, 3.20000e+01, 1.10000e+01, 2.00000e+00, 2.00000e+00]),
#  array([1.73017510e-03, 4.52919910e-01, 9.04109644e-01, 1.35529938e+00,
#         1.80648911e+00, 2.25767885e+00, 2.70886858e+00, 3.16005832e+00,
#         3.61124805e+00, 4.06243779e+00, 4.51362752e+00]),
#  <BarContainer object of 10 artists>)

# %%
Ddate=[]
for row in df_Bsurf.itertuples():
    Ddate.append(row.Index[3])
df_Bsurf['time']=Ddate

# %%
df_Bsurf['time'] = pandas.to_datetime(df_Bsurf['time']) # Convert that column into a datetime datatype

df_Bsurf.index = df_Bsurf['time'] # Set the datetime column as the index

# %%
del df_Bsurf['ETAC']
df_Bsurf
df_Bsurf=df_Bsurf.loc[:, 'LON':'IJ-AVG-S_Hg0']

# %%
df_Bsurf['time']=Ddate

# %%
#df_base.index=df_base['LAT']
LapaLat = df_Bsurf[df_Bsurf.LAT > -58]
LapanLat = LapaLat[LapaLat.LAT<18]
LapanLon=LapanLat[LapanLat.LON>-92]
LAPAN= LapanLon[LapanLon.LON<-25]
LAPAN
# Out:
#              LON   LAT  IJ-AVG-S_Hg0       time
# time
# 2015-01-01 -90.0 -56.0      0.732235 2015-01-01
# 2015-02-01 -90.0 -56.0      0.743483 2015-02-01
# 2015-03-01 -90.0 -56.0      0.743371 2015-03-01
# 2015-04-01 -90.0 -56.0      0.787097 2015-04-01
# 2015-05-01 -90.0 -56.0      0.909376 2015-05-01
# ...          ...   ...           ...        ...
# 2015-08-01 -27.5  16.0      0.055445 2015-08-01
# 2015-09-01 -27.5  16.0      0.051539 2015-09-01
# 2015-10-01 -27.5  16.0      0.042464 2015-10-01
# 2015-11-01 -27.5  16.0      0.037561 2015-11-01
# 2015-12-01 -27.5  16.0      0.038552 2015-12-01
#
# [542568 rows x 4 columns]

# %%
LAPAN_gdf = gpd.GeoDataFrame(LAPAN, geometry = gpd.points_from_xy(LAPAN['LON'],LAPAN['LAT'] ))
#LAPAN_gdf.plot(markersize = 1.5, figsize = (10,10))
LAPAN_gdf
# Out:
#              LON   LAT  IJ-AVG-S_Hg0       time                     geometry
# time
# 2015-01-01 -90.0 -56.0      0.732235 2015-01-01  POINT (-90.00000 -56.00000)
# 2015-02-01 -90.0 -56.0      0.743483 2015-02-01  POINT (-90.00000 -56.00000)
# 2015-03-01 -90.0 -56.0      0.743371 2015-03-01  POINT (-90.00000 -56.00000)
# 2015-04-01 -90.0 -56.0      0.787097 2015-04-01  POINT (-90.00000 -56.00000)
# 2015-05-01 -90.0 -56.0      0.909376 2015-05-01  POINT (-90.00000 -56.00000)
# ...          ...   ...           ...        ...                          ...
# 2015-08-01 -27.5  16.0      0.055445 2015-08-01   POINT (-27.50000 16.00000)
# 2015-09-01 -27.5  16.0      0.051539 2015-09-01   POINT (-27.50000 16.00000)
# 2015-10-01 -27.5  16.0      0.042464 2015-10-01   POINT (-27.50000 16.00000)
# 2015-11-01 -27.5  16.0      0.037561 2015-11-01   POINT (-27.50000 16.00000)
# 2015-12-01 -27.5  16.0      0.038552 2015-12-01   POINT (-27.50000 16.00000)
#
# [542568 rows x 5 columns]

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
NAmerica =world.query('continent == "North America"')
CNAmerica=NAmerica.drop([3])
CAmerica=CNAmerica.drop([4])
CAmerica=CAmerica.drop([22])
CAmerica=CAmerica.drop([27])
CAmerica=CAmerica.drop([16,17,19,45,46,47,175])
CAmerica
# Out:
#      pop_est      continent         name iso_a3  gdp_md_est  \
# 33   3753142  North America       Panama    PAN     93120.0
# 34   4930258  North America   Costa Rica    CRI     79260.0
# 35   6025951  North America    Nicaragua    NIC     33550.0
# 36   9038741  North America     Honduras    HND     43190.0
# 37   6172011  North America  El Salvador    SLV     54790.0
# 38  15460732  North America    Guatemala    GTM    131800.0
# 39    360346  North America       Belize    BLZ      3088.0
#
#                                              geometry
# 33  POLYGON ((-77.35336 8.67050, -77.47472 8.52429...
# 34  POLYGON ((-82.54620 9.56613, -82.93289 9.47681...
# 35  POLYGON ((-83.65561 10.93876, -83.89505 10.726...
# 36  POLYGON ((-83.14722 14.99583, -83.48999 15.016...
# 37  POLYGON ((-89.35333 14.42413, -89.05851 14.340...
# 38  POLYGON ((-92.22775 14.53883, -92.20323 14.830...
# 39  POLYGON ((-89.14308 17.80832, -89.15091 17.955...

# %%
mx=LAPAN_gdf['IJ-AVG-S_Hg0'].max()
mn=LAPAN_gdf['IJ-AVG-S_Hg0'].min()

# %%
SAmerica = world.query('continent == "South America"')
#NAmerica =world.query('continent == "North America"')
fig, ax = plt.subplots(figsize = (15,15))


CAmerica.plot(ax=ax,color='white', edgecolor='gray' )
SAmerica.plot(ax=ax,color='white', edgecolor='gray' )
LAPAN_gdf.plot(ax=ax,column='IJ-AVG-S_Hg0', categorical=True, \
        k=10, cmap='OrRd', linewidth=0.1, \
        edgecolor='white', legend=True )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-4806526cb3b9> in <module>
#       6 CAmerica.plot(ax=ax,color='white', edgecolor='gray' )
#       7 SAmerica.plot(ax=ax,color='white', edgecolor='gray' )
# ----> 8 LAPAN_gdf.plot(ax=ax,column='IJ-AVG-S_Hg0', categorical=True, \
#       9         k=10, cmap='OrRd', linewidth=0.1, \
#      10         edgecolor='white', legend=True )
#
# ~/anaconda3/envs/UniToro/lib/python3.8/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     919         from there.
#     920         """
# --> 921         return plot_dataframe(self, *args, **kwargs)
#     922
#     923     plot.__doc__ = plot_dataframe.__doc__
#
# ...

# %%
Lapan= pd.read_csv('Lapan.csv')
# Creating GeoPandas GeoDataFrame using the Pandas Dataframe 
Lapan_gdf = gpd.GeoDataFrame(Lapan, geometry = gpd.points_from_xy(Lapan['Longitude'],Lapan['Latitude'] ))
Lapan_gdf

Lapan2 = Lapan_gdf.drop([13])
Lapan2
# Out:
#                                 Site   Latitude  Longitude Date of deployment  \
# 0           Iguaçu National Park, PR -25.626736 -54.478653         2017-10-20
# 1          São José dos Ausentes, RS -28.596650 -49.813100         2017-11-16
# 2                    Rocas Atoll, RN  -3.856411 -33.817428         2017-11-20
# 3          Cristalino State Park, MT  -9.597813 -55.932276         2017-12-05
# 4      Abrolhos (Redonda Island), BA -18.131667 -38.797778         2018-01-16
# 5                     Rio Grande, RS -32.068906 -52.161475         2018-02-01
# 6                      Puruzinho, AM  -7.370556 -63.059444         2018-03-24
# 7         Itatiaia National Park, RJ -22.385833 -44.678889         2018-03-27
# 8           São Luis do maranhão, MA  -2.593833 -44.211194         2018-04-06
# 9                    Nova Nazaré, MT -13.958617 -51.776933         2018-04-13
# 10                         Moeda, MG -20.352322 -43.952511         2018-04-20
# ...

# %%
LAPAN_gdf
# Out:
#              LON   LAT  IJ-AVG-S_Hg0       time                     geometry
# time
# 2015-01-01 -90.0 -56.0      0.732235 2015-01-01  POINT (-90.00000 -56.00000)
# 2015-02-01 -90.0 -56.0      0.743483 2015-02-01  POINT (-90.00000 -56.00000)
# 2015-03-01 -90.0 -56.0      0.743371 2015-03-01  POINT (-90.00000 -56.00000)
# 2015-04-01 -90.0 -56.0      0.787097 2015-04-01  POINT (-90.00000 -56.00000)
# 2015-05-01 -90.0 -56.0      0.909376 2015-05-01  POINT (-90.00000 -56.00000)
# ...          ...   ...           ...        ...                          ...
# 2015-08-01 -27.5  16.0      0.055445 2015-08-01   POINT (-27.50000 16.00000)
# 2015-09-01 -27.5  16.0      0.051539 2015-09-01   POINT (-27.50000 16.00000)
# 2015-10-01 -27.5  16.0      0.042464 2015-10-01   POINT (-27.50000 16.00000)
# 2015-11-01 -27.5  16.0      0.037561 2015-11-01   POINT (-27.50000 16.00000)
# 2015-12-01 -27.5  16.0      0.038552 2015-12-01   POINT (-27.50000 16.00000)
#
# [542568 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize = (15,15))
CAmerica.plot(ax=ax,color='white', edgecolor='gray' )
SAmerica.plot(ax=ax,color='white', edgecolor='gray' )
Lapan_gdf.plot(ax=ax,marker='o', color='blue', markersize=20)
LAPAN_gdf.plot(ax=ax,marker='o', color='red', markersize=5)
# Out:
# <AxesSubplot:>

# %%
LAPAN_gdf[:50]
# Out:
#              LON   LAT  IJ-AVG-S_Hg0       time                     geometry
# time
# 2015-01-01 -90.0 -56.0      0.732235 2015-01-01  POINT (-90.00000 -56.00000)
# 2015-02-01 -90.0 -56.0      0.743483 2015-02-01  POINT (-90.00000 -56.00000)
# 2015-03-01 -90.0 -56.0      0.743371 2015-03-01  POINT (-90.00000 -56.00000)
# 2015-04-01 -90.0 -56.0      0.787097 2015-04-01  POINT (-90.00000 -56.00000)
# 2015-05-01 -90.0 -56.0      0.909376 2015-05-01  POINT (-90.00000 -56.00000)
# 2015-06-01 -90.0 -56.0      0.960084 2015-06-01  POINT (-90.00000 -56.00000)
# 2015-07-01 -90.0 -56.0      1.020590 2015-07-01  POINT (-90.00000 -56.00000)
# 2015-08-01 -90.0 -56.0      1.030847 2015-08-01  POINT (-90.00000 -56.00000)
# 2015-09-01 -90.0 -56.0      1.040254 2015-09-01  POINT (-90.00000 -56.00000)
# 2015-10-01 -90.0 -56.0      1.001661 2015-10-01  POINT (-90.00000 -56.00000)
# 2015-11-01 -90.0 -56.0      0.849405 2015-11-01  POINT (-90.00000 -56.00000)
# ...

# %%
Long= LAPAN.groupby('LON')
Long.groups.keys();

# %%
Lkey =Long.groups.keys() 
Hg0 = []
longit = []
latitu = []
for long in Lkey:
    Lgroup = Long.get_group(long).groupby('LAT')
    key =  Lgroup.groups.keys()
    for item in key:
        
        longi = Lgroup.get_group(item).mean()[0]
        longit.append(longi)
        latit=Lgroup.get_group(item).mean()[1]
        latitu.append(latit)
        HG = Lgroup.get_group(item).mean()[2]
        Hg0.append(HG)

    
df2= pd.DataFrame({"LON":longit,"LAT":latitu,"IJ-AVG-S_Hg0":Hg0})
df2
# Out:
# <ipython-input-25-2b3e5bcaa3be>:10: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   longi = Lgroup.get_group(item).mean()[0]
# <ipython-input-25-2b3e5bcaa3be>:12: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   latit=Lgroup.get_group(item).mean()[1]
# <ipython-input-25-2b3e5bcaa3be>:14: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   HG = Lgroup.get_group(item).mean()[2]
#       LON   LAT  IJ-AVG-S_Hg0
# 0   -90.0 -56.0      0.530230
# 1   -90.0 -54.0      0.534771
# 2   -90.0 -52.0      0.540477
# 3   -90.0 -50.0      0.545026
# 4   -90.0 -48.0      0.549657
# ..    ...   ...           ...
# 957 -27.5   8.0      0.908470
# 958 -27.5  10.0      0.905916
# 959 -27.5  12.0      0.897345
# ...

# %%
Hg0
# Out:
# [0.5302296254734057,
#  0.5347707618691883,
#  0.54047721650046,
#  0.5450257921612426,
#  0.5496568940171196,
#  0.5549442716932158,
#  0.5594016546090039,
#  0.5632300042836297,
#  0.5671824532417212,
#  0.5727322063526664,
#  0.5810039705088804,
#  0.5895247453252441,
#  0.5978980538388217,
#  0.607465183925835,
#  0.6162614893910572,
#  0.6256633773146435,
#  0.6363712108253722,
#  0.647789840263479,
#  0.6606109679808269,
#  0.6755415676379748,
#  0.6961176485780616,
#  0.7217680559727029,
#  0.7512869941787388,
#  0.7834418741896546,
#  0.8150550150901017,
#  0.8412021471187956,
#  0.8669988852763706,
#  0.8877854480811758,
#  0.9001022553340093,
#  0.9050201624931922,
#  0.9061470766925104,
#  0.9049423465735622,
#  0.901378884474707,
#  0.9007276260254649,
#  0.9040298465128396,
#  0.9091628154193647,
#  0.8815412020255682,
#  0.5305446217378429,
#  0.5348725085060337,
#  0.5403464115659801,
#  0.544785795657746,
#  0.5492480939286835,
#  0.5542015514642582,
# ...

# %%
 df_Latin = gpd.GeoDataFrame(df2 , geometry = gpd.points_from_xy(df2['LON'],df2['LAT'] ))

# %%
def legend_without_duplicate_labels(ax):
    handles, labels = ax.get_legend_handles_labels()
    unique = [(h, l) for i, (h, l) in enumerate(zip(handles, labels)) if l not in labels[:i]]
    ax.legend(*zip(*unique))

# %%
fig, ax = plt.subplots(figsize = (15,15))
CAmerica.plot(ax=ax,color='white', edgecolor='gray' )
SAmerica.plot(ax=ax,color='white', edgecolor='gray' )
Lapan_gdf.plot(ax=ax,marker='o', color='blue', markersize=20,label='$Hg^0_{obs}$')
df_Latin.plot(ax=ax,marker='o', color='red', markersize=20,label='$Hg^0_{GChem}$')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title('Location of Observation Sites in South America Relative to GEOS Chem 2X2.5 Grid Output ')
legend_without_duplicate_labels(ax)

# %%
df2
cods=[]
for i, j in df2.iterrows(): 
    coord=(j['LAT'],j['LON'])
    cods.append(coord)
cods
# Out:
# [(-56.0, -90.0),
#  (-54.0, -90.0),
#  (-52.0, -90.0),
#  (-50.0, -90.0),
#  (-48.0, -90.0),
#  (-46.0, -90.0),
#  (-44.0, -90.0),
#  (-42.0, -90.0),
#  (-40.0, -90.0),
#  (-38.0, -90.0),
#  (-36.0, -90.0),
#  (-34.0, -90.0),
#  (-32.0, -90.0),
#  (-30.0, -90.0),
#  (-28.0, -90.0),
#  (-26.0, -90.0),
#  (-24.0, -90.0),
#  (-22.0, -90.0),
#  (-20.0, -90.0),
#  (-18.0, -90.0),
#  (-16.0, -90.0),
#  (-14.0, -90.0),
#  (-12.0, -90.0),
#  (-10.0, -90.0),
#  (-8.0, -90.0),
#  (-6.0, -90.0),
#  (-4.0, -90.0),
#  (-2.0, -90.0),
#  (0.0, -90.0),
#  (2.0, -90.0),
#  (4.0, -90.0),
#  (6.0, -90.0),
#  (8.0, -90.0),
#  (10.0, -90.0),
#  (12.0, -90.0),
#  (14.0, -90.0),
#  (16.0, -90.0),
#  (-56.0, -87.5),
#  (-54.0, -87.5),
#  (-52.0, -87.5),
#  (-50.0, -87.5),
#  (-48.0, -87.5),
#  (-46.0, -87.5),
#  (-44.0, -87.5),
#  (-42.0, -87.5),
#  (-40.0, -87.5),
#  (-38.0, -87.5),
#  (-36.0, -87.5),
#  (-34.0, -87.5),
#  (-32.0, -87.5),
#  (-30.0, -87.5),
#  (-28.0, -87.5),
#  (-26.0, -87.5),
# ...

# %% [markdown]
# ## Interpolate to get the GEOS-Chem run data at observational points

# %%
import numpy as np
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return array[idx]

array = np.random.random(10)
print(array)
# [ 0.21069679  0.61290182  0.63425412  0.84635244  0.91599191  0.00213826
#   0.17104965  0.56874386  0.57319379  0.28719469]

value = 0.5

print(find_nearest(array, value))
# 0.568743859261
# Out:
# [0.39343819 0.34195415 0.46569281 0.35050006 0.60499894 0.9652599
#  0.39977288 0.72303948 0.1163435  0.66870744]
# 0.46569281391448536

# %%
from scipy import spatial
airports = cods
tree = spatial.KDTree(airports)
df2.iloc[tree.query([(-25.626736,-54.478653)])[1][0]][2]
# Out:
# 0.7422167081281565

# %%
tree = spatial.KDTree(cods)
GEOS = []
for i, j in Lapan_gdf.iterrows():
    
    point=df2.iloc[tree.query([(j['Latitude'],j['Longitude'])])[1][0]][2]
    GEOS.append(point)
GEOS
# Out:
# [0.7422167081281565,
#  0.7123562486148342,
#  0.8103317097115739,
#  0.8216881580649775,
#  0.7407427911650919,
#  0.6526930388146324,
#  0.8511228986831927,
#  0.7631147267610932,
#  0.8329481764818585,
#  0.7996270296363034,
#  0.7675748572828082,
#  0.7125323276857033,
#  0.7545979502881736,
#  0.8708784025469288,
#  0.6526930388146324,
#  0.5311335677593462,
#  0.9610831439305697,
#  0.8752345264903506,
#  1.176782833596657,
#  0.9161197647173359,
#  1.0244726250464309,
#  0.9072404784978645,
#  0.9072404784978645,
#  0.9254852381959794,
#  0.8945042385398753,
#  0.5701198229501818,
#  0.5880949696581489,
#  0.7727793089205647]

# %%
cods[926]
# Out:
# (-54.0, -27.5)

# %%
#create a two dimentional array with the geoschem outputs in the South America Region
Matrix = np.zeros((37,26)); 
lonlon =[] # create an empty array to store longitude coordinates

j=0 #initialise the count for matrix column
for item in df2.groupby('LON').groups.keys():
    i=0
    lonlon.append(item)
    latlat = [] #create an empty array to store latitude coordinates
    for row in df2.groupby('LON').get_group(item).itertuples():
        Matrix[i][j]=row[3]
        latlat.append(row[2]) 
        i = i+1
      
    j= j+1

# %%
from scipy.interpolate import griddata
from scipy.interpolate import interp2d
import matplotlib.pyplot as plt

x = lonlon
y = latlat

GC_Hg0_2015_av = Matrix
# Choose npts random point from the discrete domain of our model function

px = Lapan_gdf['Longitude']
py = Lapan_gdf['Latitude']

# Interpolate using the cubic method 
f= interp2d(x,y,GC_Hg0_2015_av, kind='cubic')

# %%
df2
# Out:
#       LON   LAT  IJ-AVG-S_Hg0                     geometry
# 0   -90.0 -56.0      0.530230  POINT (-90.00000 -56.00000)
# 1   -90.0 -54.0      0.534771  POINT (-90.00000 -54.00000)
# 2   -90.0 -52.0      0.540477  POINT (-90.00000 -52.00000)
# 3   -90.0 -50.0      0.545026  POINT (-90.00000 -50.00000)
# 4   -90.0 -48.0      0.549657  POINT (-90.00000 -48.00000)
# ..    ...   ...           ...                          ...
# 957 -27.5   8.0      0.908470    POINT (-27.50000 8.00000)
# 958 -27.5  10.0      0.905916   POINT (-27.50000 10.00000)
# 959 -27.5  12.0      0.897345   POINT (-27.50000 12.00000)
# 960 -27.5  14.0      0.885279   POINT (-27.50000 14.00000)
# 961 -27.5  16.0      0.871829   POINT (-27.50000 16.00000)
#
# [962 rows x 4 columns]

# %%
Lapan_gdf
# Out:
#                                 Site   Latitude  Longitude Date of deployment  \
# 0           Iguaçu National Park, PR -25.626736 -54.478653         2017-10-20
# 1          São José dos Ausentes, RS -28.596650 -49.813100         2017-11-16
# 2                    Rocas Atoll, RN  -3.856411 -33.817428         2017-11-20
# 3          Cristalino State Park, MT  -9.597813 -55.932276         2017-12-05
# 4      Abrolhos (Redonda Island), BA -18.131667 -38.797778         2018-01-16
# 5                     Rio Grande, RS -32.068906 -52.161475         2018-02-01
# 6                      Puruzinho, AM  -7.370556 -63.059444         2018-03-24
# 7         Itatiaia National Park, RJ -22.385833 -44.678889         2018-03-27
# 8           São Luis do maranhão, MA  -2.593833 -44.211194         2018-04-06
# 9                    Nova Nazaré, MT -13.958617 -51.776933         2018-04-13
# 10                         Moeda, MG -20.352322 -43.952511         2018-04-20
# ...

# %%
Lapan_gdf=Lapan_gdf.sort_values('Longitude')
Lapan_gdf
# Out:
#                                 Site   Latitude  Longitude Date of deployment  \
# 24                       Tegucigalpa  14.097500 -87.202778         2017-11-14
# 22                         Abangares  10.287500 -84.955556         2018-04-23
# 21                 San Jose Downtown   9.938056 -84.075278         2018-03-24
# 23                         Corcovado   8.529278 -83.407278         2018-05-17
# 18             Rio Branco, Manizales   5.075833 -75.436944         2017-12-27
# 20                        PNN Brisas   4.971028 -75.342761         2018-01-27
# 15       Glacie Dawin (Schapiarelli) -54.414400 -70.915700         2019-04-20
# 19                            Arauca   7.012714 -70.744608         2018-01-22
# 17                 Amazonía, Leticia  -4.191528 -69.939444         2017-12-14
# 16                        Chacaltaya -16.350356 -68.131603         2018-07-05
# 25                      Villa Regina -39.102333 -67.108361         2018-05-05
# ...

# %%
LAP=pd.DataFrame()
LAP['LONG']=Lapan_gdf['Longitude']
LAP['LATI']=Lapan_gdf['Latitude']
LAP['OBS']=Lapan_gdf['Measured Conc (ng/m3)']
LAP['OBS'].iloc[14]=0.59
LAP
# Out:
# /home/tzd/anaconda3/envs/UniToro/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#          LONG       LATI   OBS
# 24 -87.202778  14.097500  1.95
# 22 -84.955556  10.287500  6.87
# 21 -84.075278   9.938056  0.71
# 23 -83.407278   8.529278  0.56
# 18 -75.436944   5.075833  1.25
# 20 -75.342761   4.971028  1.18
# 15 -70.915700 -54.414400  0.79
# 19 -70.744608   7.012714  0.91
# 17 -69.939444  -4.191528  0.97
# 16 -68.131603 -16.350356  1.68
# 25 -67.108361 -39.102333  0.79
# 27 -65.406064 -24.721342  0.99
# 6  -63.059444  -7.370556  0.79
# 26 -62.444778 -38.699528  0.95
# 13 -59.000000  -2.144000  0.59
# 3  -55.932276  -9.597813  0.57
# 0  -54.478653 -25.626736  0.63
# ...

# %%
observe=[]
for item in LAP['OBS']:
    observe.append(float(item))
observe    
LAP['OBS']=observe

# %%
tree = spatial.KDTree(cods)
GEOS = []
for i, j in LAP.iterrows():
    print(df2.iloc[tree.query([(j['LATI'],j['LONG'])])[1][0]])
    point=df2.iloc[tree.query([(j['LATI'],j['LONG'])])[1][0]][2]
    GEOS.append(point)
GEOS
# Out:
# LON                        -87.5
# LAT                           14
# IJ-AVG-S_Hg0            0.894504
# geometry        POINT (-87.5 14)
# Name: 72, dtype: object
# LON                        -85
# LAT                         10
# IJ-AVG-S_Hg0           0.90724
# geometry        POINT (-85 10)
# Name: 107, dtype: object
# LON                        -85
# LAT                         10
# IJ-AVG-S_Hg0           0.90724
# geometry        POINT (-85 10)
# Name: 107, dtype: object
# LON                       -82.5
# LAT                           8
# IJ-AVG-S_Hg0           0.925485
# geometry        POINT (-82.5 8)
# Name: 143, dtype: object
# LON                       -75
# LAT                         6
# IJ-AVG-S_Hg0          1.17678
# geometry        POINT (-75 6)
# Name: 253, dtype: object
# LON                       -75
# LAT                         4
# IJ-AVG-S_Hg0          1.02447
# geometry        POINT (-75 4)
# Name: 252, dtype: object
# LON                         -70
# ...

# %%
LAP['GChem']=GEOS
LAP
# Out:
#          LONG       LATI   OBS     GChem
# 24 -87.202778  14.097500  1.95  0.894504
# 22 -84.955556  10.287500  6.87  0.907240
# 21 -84.075278   9.938056  0.71  0.907240
# 23 -83.407278   8.529278  0.56  0.925485
# 18 -75.436944   5.075833  1.25  1.176783
# 20 -75.342761   4.971028  1.18  1.024473
# 15 -70.915700 -54.414400  0.79  0.531134
# 19 -70.744608   7.012714  0.91  0.916120
# 17 -69.939444  -4.191528  0.97  0.875235
# 16 -68.131603 -16.350356  1.68  0.961083
# 25 -67.108361 -39.102333  0.79  0.570120
# 27 -65.406064 -24.721342  0.99  0.772779
# 6  -63.059444  -7.370556  0.79  0.851123
# 26 -62.444778 -38.699528  0.95  0.588095
# 13 -59.000000  -2.144000  0.59  0.870878
# 3  -55.932276  -9.597813  0.57  0.821688
# 0  -54.478653 -25.626736  0.63  0.742217
# 5  -52.161475 -32.068906  1.00  0.652693
# 14 -52.099300 -32.033583  0.95  0.652693
# 9  -51.776933 -13.958617  0.76  0.799627
# 1  -49.813100 -28.596650  0.63  0.712356
# 12 -46.766117 -23.456314  1.22  0.754598
# ...

# %%
fig = plt.figure(figsize=[10,5])
ax = fig.add_subplot(111)
#plt.plot(listing)
plt.plot(LAP['LONG'],LAP['OBS'],'^',LAP['LONG'],LAP['GChem'],'^')

# %%
w = (28,2)
Q = np.zeros(w)
Q[:,0]=LAP['LONG']
Q[:,1]=LAP['LATI']
Q
# Out:
# array([[-87.20277778,  14.0975    ],
#        [-84.95555556,  10.2875    ],
#        [-84.07527778,   9.93805556],
#        [-83.40727778,   8.52927778],
#        [-75.43694444,   5.07583333],
#        [-75.34276111,   4.97102778],
#        [-70.9157    , -54.4144    ],
#        [-70.74460833,   7.01271389],
#        [-69.93944444,  -4.19152778],
#        [-68.13160278, -16.35035556],
#        [-67.10836111, -39.10233333],
#        [-65.40606389, -24.72134167],
#        [-63.05944444,  -7.37055556],
#        [-62.44477778, -38.69952778],
#        [-59.        ,  -2.144     ],
#        [-55.93227611,  -9.59781278],
#        [-54.47865278, -25.62673611],
#        [-52.161475  , -32.06890556],
#        [-52.0993    , -32.03358333],
#        [-51.77693333, -13.95861667],
#        [-49.8131    , -28.59665   ],
#        [-46.76611667, -23.45631389],
#        [-44.67888889, -22.38583333],
#        [-44.21119444,  -2.59383333],
#        [-43.95251111, -20.35232222],
# ...

# %% [markdown]
# ### Interpolation with inverse-distance-weighted interpolation

# %%
s = (962,2)
D = np.zeros(s)
D[:,0]=df2['LON']
D[:,1]=df2['LAT']
D
# Out:
# array([[-90. , -56. ],
#        [-90. , -54. ],
#        [-90. , -52. ],
#        ...,
#        [-27.5,  12. ],
#        [-27.5,  14. ],
#        [-27.5,  16. ]])

# %%
import numpy as np
import matplotlib.pyplot as plt
import idw

# create sample points with structured scores
X1 = D

def func(x, y):
    return np.sin(x**2 + y**2) / (x**2 + y**2)

z1 = df2['IJ-AVG-S_Hg0']

# 'train'
idw_tree = idw.tree(X1, z1)

# 'test'
spacing = np.linspace(-90., 30., 100)
X2 = Q
grid_shape = X2[0].shape
z2 = idw_tree(X2)

z2
# Out:
# array([0.89274987, 0.90627313, 0.90915822, 0.92093625, 1.06681899,
#        1.04716155, 0.53164199, 0.93355638, 0.87493746, 0.9638789 ,
#        0.57582057, 0.75838615, 0.85292219, 0.58539201, 0.86768786,
#        0.82769355, 0.74346608, 0.65079283, 0.65072255, 0.7960044 ,
#        0.70574816, 0.7505036 , 0.75745885, 0.82898685, 0.7596695 ,
#        0.73812423, 0.81278999, 0.71030163])

# %% [markdown]
# ### Interpolating Using RBF

# %%
X = df2['LON']
Y = df2['LAT']

GC_Hg0_2015_av = Matrix
# Choose npts random point from the discrete domain of our model function

px = Lapan_gdf['Longitude']
py = Lapan_gdf['Latitude']

# Interpolate using the cubic m

rbf = Rbf(X, Y,GC_Hg0_2015_av,epsilon=2)

# %%
#generate model outputs at the LAPAN sites 
Interp_Output = []
for i in range(28):
    Interp_Output.append(f(px[i],py[i])[0])

# %% [markdown]
# ## Compare GEOS_Chem Output with the Measured Data

# %%
#Get measured data
Lapan_gdf['Measured Conc (ng/m3)']
Lapan_gdf
LAPAN_site_Hg0 = pd.DataFrame(columns=['site', 'Hg0_M_C(ng/m3)'])
LAPAN_site_Hg0['site']=Lapan_gdf['Site']
LAPAN_site_Hg0['Hg0_M_C(ng/m3)']=Lapan_gdf['Measured Conc (ng/m3)']
LAPAN_site_Hg0
# Out:
#                                 site                     Hg0_M_C(ng/m3)
# 24                       Tegucigalpa                               1.95
# 22                         Abangares                               6.87
# 21                 San Jose Downtown                               0.71
# 23                         Corcovado                               0.56
# 18             Rio Branco, Manizales                               1.25
# 20                        PNN Brisas                               1.18
# 15       Glacie Dawin (Schapiarelli)                               0.79
# 19                            Arauca                               0.91
# 17                 Amazonía, Leticia                               0.97
# 16                        Chacaltaya                               1.68
# 25                      Villa Regina                               0.79
# 27                             Salta                               0.99
# ...

# %%
#Select the value that should be used in Manaus
LAPAN_site_Hg0['Hg0_M_C(ng/m3)'][13]=0.59
LAPAN_site_Hg0

# %%
#convert concentration values in to floats
data=np.array(LAPAN_site_Hg0['Hg0_M_C(ng/m3)'])
data
listing=[float(i) for i in data]
LAPAN_site_Hg0['Hg0_M_C(ng/m3)']=listing
LAPAN_site_Hg0

# %%
fig = plt.figure(figsize=[10,5])
ax = fig.add_subplot(111)
#plt.plot(listing)
plt.plot(range(0, 28),LAPAN_site_Hg0['Hg0_M_C(ng/m3)'],'^',range(0, 28),z2,'^',range(0, 28),GEOS,'^')

# %%
df_compare = LAPAN_site_Hg0
df_compare['GChem']=Interp_Output
df_compare['GEOS']=GEOS
df_compare =df_compare.drop(index=22)
df_compare

# %%
LAP
LAPA = LAP.drop(index=22)
LAPA

# %%
#Create a basic scatter plot with Matplotlib
#A identity line was created based on the minumum and maximum observed value
#Points markers are colored by the residual and a residual colorbar is added to the figure
LAPA['Residual'] = LAPA['GChem']- LAPA['OBS']
fig = plt.figure(figsize=(10,8))
x = np.linspace(LAPA['OBS'].min(),LAPA['OBS'].max(), 100)
plt.plot(x, x, linestyle='dashed')
plt.scatter(LAPA['OBS'],LAPA['GChem'], marker='o', c=LAPA['Residual'])

cbar = plt.colorbar()
cbar.set_label('Difference (ng/m3)', fontsize=14)

plt.grid()
plt.xlabel('Observed Concentration (ng/m3)', fontsize=14)
plt.ylabel('Simulated Concentration (ng/m3)', fontsize=14)
fig.tight_layout()
#fig.savefig('../Figures/ObservedSimulatedHeadComparisonPlot.png')

# %%
#Create a basic scatter plot with Matplotlib
#A identity line was created based on the minumum and maximum observed value
#Points markers are colored by the residual and a residual colorbar is added to the figure
df_compare['Residual'] = df_compare['GEOS']- df_compare['Hg0_M_C(ng/m3)']
fig = plt.figure(figsize=(10,8))
x = np.linspace(df_compare['Hg0_M_C(ng/m3)'].min(),df_compare['Hg0_M_C(ng/m3)'].max(), 100)
plt.plot(x, x, linestyle='dashed')
plt.scatter(df_compare['Hg0_M_C(ng/m3)'],df_compare['GEOS'], marker='o', c=df_compare['Residual'])

cbar = plt.colorbar()
cbar.set_label('Difference (ng/m3)', fontsize=14)

plt.grid()
plt.xlabel('Observed Concentration (ng/m3)', fontsize=14)
plt.ylabel('Simulated Concentration (ng/m3)', fontsize=14)
fig.tight_layout()
#fig.savefig('../Figures/ObservedSimulatedHeadComparisonPlot.png')

# %%
from scipy import stats

x = df_compare['GEOS']
y= df_compare['Hg0_M_C(ng/m3)']
slope, intercept, r_value, _, _ = stats.linregress(x, y)
m = slope.astype(float)
#Create a basic scatter plot with Matplotlib
#A identity line was created based on the minumum and maximum observed value
#Points markers are colored by the residual and a residual colorbar is added to the figure
#df_compare['Residual'] = df_compare['GChem']- df_compare['Hg0_M_C(ng/m3)']
fig = plt.figure(figsize=(10,8))
z = np.linspace(y.min(),y.max(), 100)
plt.plot(z, z, linestyle='dashed',label="1:1 line")
plt.scatter(x,y, marker='o',color="purple",label="Data")
plt.plot(x, m*x + intercept, 'grey', label='regression fitted line')

#cbar = plt.colorbar()
#cbar.set_label('Residual (ng/m3)', fontsize=14)

plt.grid()
plt.legend()
plt.xlabel('Simulated Concentration (ng/m3)', fontsize=14)
plt.ylabel('Observed  Concentration (ng/m3)', fontsize=14)
fig.tight_layout()
#fig.savefig('../Figures/ObservedSimulatedHeadComparisonPlot.png')

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
#(df_compare['Hg0_M_C(ng/m3)'], df_compare['GChem'])
# Create data frame. The last column is the needed color


df = pd.DataFrame()
df['Hg0_M_C(ng/m3)']=df_compare['Hg0_M_C(ng/m3)']
df['GChem']=df_compare['GChem']
# Add a column: the color depends of x and y values, but you can use whatever function.
value=(df_compare['Hg0_M_C(ng/m3)']<df_compare['GChem'])
df['color']= np.where( value==True , "#9b59b6", "#3498db")

# plot
sns.regplot(data=df, x="Hg0_M_C(ng/m3)", y="GChem", fit_reg=False, scatter_kws={'facecolors':df['color']})
#sns.plt.show()

# %%
value

# %%
data = (df_compare['Hg0_M_C(ng/m3)'], df_compare['GChem'])
data

# %%
df_compare['GChem_rbf']=out

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 60
g1 = (0.6 + 0.6 * np.random.rand(N), np.random.rand(N))
g2 = (0.4+0.3 * np.random.rand(N), 0.5*np.random.rand(N))
g3 = (0.3*np.random.rand(N),0.3*np.random.rand(N))

data = (g1, g2, g3)
colors = ("red", "green", "blue")
groups = ("coffee", "tea", "water")

# Create plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

for data, color, group in zip(data, colors, groups):
    x, y = data
    ax.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)

plt.title('Matplot scatter plot')
plt.legend(loc=2)
plt.show()

# %%
N = 60
g1 = (0.6 + 0.6 * np.random.rand(N), np.random.rand(N))
g2 = (0.4+0.3 * np.random.rand(N), 0.5*np.random.rand(N))
g3 = (0.3*np.random.rand(N),0.3*np.random.rand(N))

data = (g1, g2, g3)
data

# %%
df_compare['GChem_idw']=z2
# '''error bar information'''
#standard deviation calculated here
stdHg0idw=df_compare['GChem_idw'].std()
#calculate standard error of mean
semHg0idw=df_compare['GChem_idw'].sem()

# %%
#find the difference between the GEOSchem output and the observations
df_d=df_compare['Hg0_M_C(ng/m3)']-df_compare['GChem']


Hg0concav=df_d.mean()

# '''error bar information'''
#standard deviation calculated here
stdHg0=df_d.std()
#calculate standard error of mean
semHg0=df_d.sem()
print(semHg0)

##making std and sem values into list
'''stdHg0list=[]
semHg0list=[]
for ind in range(len(stdHg0)):
    stdHg0list.append(stdHg0[ind])
    semHg0list.append(semHg0[ind])'''
Hg0concav

# %%
labels = df_compare['site']
Hg0obs = df_compare['Hg0_M_C(ng/m3)']
Hg0_GC = df_compare['GChem']

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=[11,6])
rects1 = ax.bar(x - width/2, Hg0obs, width, label='$Hg^0_{obs}$')
rects2 = ax.bar(x + width/2, Hg0_GC, width, label='$Hg^0_{GChem}$')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('$Hg^0 (ngm^{-3})$')
ax.set_title('Comparison between observed $Hg^0$ annual averages and GEOS Chem $Hg^0$ annual averages at vrious locations in South America ')
ax.set_xticks(x)
ax.set_xticklabels(labels,rotation='vertical')
#plt.xticks(x, labels, rotation='vertical')
ax.legend()

plt.show()

# %%
labels = df_compare['site'].drop(index=22)
Hg0obs = df_compare['Hg0_M_C(ng/m3)'].drop(index=22)
Hg0_GC = df_compare['GChem'].drop(index=22)

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=[11,6])
rects1 = ax.bar(x - width/2, Hg0obs, width, label='$Hg^0_{obs}$')
rects2 = ax.bar(x + width/2, Hg0_GC, width, label='$Hg^0_{GChem}$')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('$Hg^0 (ngm^{-3})$')
ax.set_title('Comparison between observed $Hg^0$ annual averages and GEOS Chem $Hg^0$ annual averages at vrious locations in South America ')
ax.set_xticks(x)
ax.set_xticklabels(labels,rotation='vertical')
#plt.xticks(x, labels, rotation='vertical')
ax.legend()

plt.show()

# %%
labels = df_compare['site']
Hg0obs = df_compare['Hg0_M_C(ng/m3)']
Hg0_GC = df_compare['GChem']

x = range(1,29)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=[11,6])
rects1 = ax.plot(x,Hg0obs,'o-', label='$Hg^0_{obs}$')
rects2 = ax.plot(x,Hg0_GC,'o-', label='$Hg^0_{GChem}$')
plt.errorbar(x,Hg0_GC, yerr=semHg0, capsize=5.0, barsabove=True)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('$Hg^0 (ngm^{-3})$')
ax.set_title('Comparison between observed $Hg^0$ annual averages and GEOS Chem $Hg^0$ annual averages at vrious locations in South America ')
ax.set_xticks(x)
ax.set_xticklabels(labels,rotation=40, ha='right')
#plt.xticks(x, labels, rotation='vertical')
#ax.legend()
legend_without_duplicate_labels(ax)

plt.show()

# %%
labels = df_compare['site'].drop(index=22)
Hg0obs = df_compare['Hg0_M_C(ng/m3)'].drop(index=22)
Hg0_GC = df_compare['GChem'].drop(index=22)

x = range(1,28)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=[11,6])
rects1 = ax.plot(x,Hg0obs,'o-', label='$Hg^0_{obs}$')
rects2 = ax.plot(x,Hg0_GC,'o-', label='$Hg^0_{GChem}$')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('$Hg^0 (ngm^{-3})$')
ax.set_title('Comparison between observed $Hg^0$ annual averages and GEOS Chem $Hg^0$ annual averages at vrious locations in South America ')
ax.set_xticks(x)
ax.set_xticklabels(labels,rotation=40, ha='right')
#plt.xticks(x, labels, rotation='vertical')
#ax.legend()
legend_without_duplicate_labels(ax)

plt.show()

# %% [markdown]
# ### RBF plots

# %%
labels = df_compare['site']
Hg0obs = df_compare['Hg0_M_C(ng/m3)']
Hg0_GC = df_compare['GChem_rbf']

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=[11,6])
rects1 = ax.bar(x - width/2, Hg0obs, width, label='$Hg^0_{obs}$')
rects2 = ax.bar(x + width/2, Hg0_GC, width, label='$Hg^0_{GChem}$')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('$Hg^0 (ngm^{-3})$')
ax.set_title('Comparison between observed $Hg^0$ annual averages and GEOS Chem $Hg^0$ annual averages at vrious locations in South America ')
ax.set_xticks(x)
ax.set_xticklabels(labels,rotation='vertical')
#plt.xticks(x, labels, rotation='vertical')
ax.legend()

plt.show()

# %%
labels = df_compare['site'].drop(index=22)
Hg0obs = df_compare['Hg0_M_C(ng/m3)'].drop(index=22)
Hg0_GC = df_compare['GChem_rbf'].drop(index=22)
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=[11,6])
rects1 = ax.bar(x - width/2, Hg0obs, width, label='$Hg^0_{obs}$')
rects2 = ax.bar(x + width/2, Hg0_GC, width, label='$Hg^0_{GChem}$')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('$Hg^0 (ngm^{-3})$')
ax.set_title('Comparison between observed $Hg^0$ annual averages and GEOS Chem $Hg^0$ annual averages at vrious locations in South America ')
ax.set_xticks(x)
ax.set_xticklabels(labels,rotation='vertical')
#plt.xticks(x, labels, rotation='vertical')
ax.legend()

plt.show()

# %%
labels = df_compare['site'].drop(index=22)
Hg0obs = df_compare['Hg0_M_C(ng/m3)'].drop(index=22)
Hg0_GC = df_compare['GChem_rbf'].drop(index=22)

x = range(1,28)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=[11,6])
rects1 = ax.plot(x,Hg0obs,'o-', label='$Hg^0_{obs}$')
rects2 = ax.plot(x,Hg0_GC,'o-', label='$Hg^0_{GChem}$')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('$Hg^0 (ngm^{-3})$')
ax.set_title('Comparison between observed $Hg^0$ annual averages and GEOS Chem $Hg^0$ annual averages at vrious locations in South America ')
ax.set_xticks(x)
ax.set_xticklabels(labels,rotation=40, ha='right')
#plt.xticks(x, labels, rotation='vertical')
#ax.legend()
legend_without_duplicate_labels(ax)

plt.show()

# %%
dfcomp=df_compare.drop(index=22)
dfcomp

# %%
longgg =[]
for item in LAPA['LONG']:
    longgg.append(round(item, 2))
longgg

# %%
labels = longgg
Hg0obs = LAPA['OBS']
Hg0_GC = LAPA['GChem']

x = longgg  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=[11,6])
rects1 = ax.plot(x,Hg0obs,'o-', label='$Hg^0_{obs}$')
rects2 = ax.plot(x,Hg0_GC,'o-', label='$Hg^0_{GChem}$')
#plt.errorbar(x,Hg0_GC, yerr=semHg0idw, capsize=5.0, barsabove=True)
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('$Hg^0 (ngm^{-3})$')
ax.set_title('Comparison between observed $Hg^0$ annual averages and GEOS Chem $Hg^0$ annual averages at vrious locations in South America ')
ax.set_xticks(x)
ax.set_xticklabels(labels,rotation=40, ha='right')
#plt.xticks(x, labels, rotation='vertical')
#ax.legend()
legend_without_duplicate_labels(ax)

plt.show()

# %%
df_compare

# %%
labels = df_compare['site']
Hg0obs = df_compare['Hg0_M_C(ng/m3)']
Hg0_GC = df_compare['GChem']

x = range(1,29)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=[11,6])
rects1 = ax.plot(x,Hg0obs,'o-', label='$Hg^0_{obs}$')
#rects2 = ax.plot(x,Hg0_GC,'o-', label='$Hg^0_{GChem}$')
#plt.errorbar(x,Hg0_GC, yerr=semHg0, capsize=5.0, barsabove=True)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('$Hg^0 (ngm^{-3})$')
ax.set_title('Observed $Hg^0$ annual averages annual averages at vrious locations in South America ')
ax.set_xticks(x)
ax.set_xticklabels(labels,rotation=40, ha='right')
#plt.xticks(x, labels, rotation='vertical')
#ax.legend()
#legend_without_duplicate_labels(ax)

plt.show()

# %%
#Create a basic scatter plot with Matplotlib
#A identity line was created based on the minumum and maximum observed value
#Points markers are colored by the residual and a residual colorbar is added to the figure
df_compare['Residual'] = df_compare['GEOS']- df_compare['Hg0_M_C(ng/m3)']
fig = plt.figure(figsize=(10,8))
x = np.linspace(df_compare['Hg0_M_C(ng/m3)'].min(),df_compare['Hg0_M_C(ng/m3)'].max(), 100)
plt.plot(x, x, linestyle='dashed')
plt.scatter(df_compare['Hg0_M_C(ng/m3)'],df_compare['GEOS'], marker='o', c=df_compare['Residual'])

cbar = plt.colorbar()
cbar.set_label('Difference (ng/m3)', fontsize=14)

plt.grid()
plt.xlabel('Observed Concentration (ng/m3)', fontsize=14)
plt.ylabel('Simulated Concentration (ng/m3)', fontsize=14)
fig.tight_layout()
#fig.savefig('../Figures/ObservedSimulatedHeadComparisonPlot.png')

# %%
df_compare
