# %%
# Run this cell to render a mitosheet
# See mito's documentation here: https://docs.trymito.io/how-to/creating-a-mitosheet
# Join our Discord for support here: https://discord.gg/XdJSZyejJU

import mitosheet
mitosheet.sheet()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /Users/shakes/Dropbox/Apps/Overleaf/Thandolwethu Dlamini Thesis/templates/JPnotebooks/stats/mito-starter-notebook.ipynb Cell 1 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/shakes/Dropbox/Apps/Overleaf/Thandolwethu%20Dlamini%20Thesis/templates/JPnotebooks/stats/mito-starter-notebook.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> # Run this cell to render a mitosheet
#       <a href='vscode-notebook-cell:/Users/shakes/Dropbox/Apps/Overleaf/Thandolwethu%20Dlamini%20Thesis/templates/JPnotebooks/stats/mito-starter-notebook.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> # See mito's documentation here: https://docs.trymito.io/how-to/creating-a-mitosheet
#       <a href='vscode-notebook-cell:/Users/shakes/Dropbox/Apps/Overleaf/Thandolwethu%20Dlamini%20Thesis/templates/JPnotebooks/stats/mito-starter-notebook.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> # Join our Discord for support here: https://discord.gg/XdJSZyejJU
#       <a href='vscode-notebook-cell:/Users/shakes/Dropbox/Apps/Overleaf/Thandolwethu%20Dlamini%20Thesis/templates/JPnotebooks/stats/mito-starter-notebook.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> import mitosheet
# ----> <a href='vscode-notebook-cell:/Users/shakes/Dropbox/Apps/Overleaf/Thandolwethu%20Dlamini%20Thesis/templates/JPnotebooks/stats/mito-starter-notebook.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> mitosheet.sheet()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mitosheet/mito_widget.py:290, in sheet(analysis_to_replay, view_df, *args)
#     288 if is_in_vs_code() or is_in_google_colab():
#     289     log('mitosheet_sheet_call_location_failed', failed=True)
# --> 290     raise Exception("The mitosheet currently only works in JupyterLab.\n\nTo see instructions on getting Mitosheet running in JupyterLab, find install instructions here: https://docs.trymito.io/getting-started/installing-mito")
#     292 # If the user.json does not exist, we create it. This ensures if the file is deleted in between
#     293 # when the package is imported and mitosheet.sheet is called, the user still gets a user.json.
#     294 # We don't need to upgrade as creating the file will automatically use the most recent version
#     295 if not os.path.exists(USER_JSON_PATH):
#
# Exception: The mitosheet currently only works in JupyterLab.
#
# To see instructions on getting Mitosheet running in JupyterLab, find install instructions here: https://docs.trymito.io/getting-started/installing-mito
